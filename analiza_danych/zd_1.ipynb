# %%
import pandas as pd
import sklearn as sc
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_csv("https://raw.githubusercontent.com/paq88/Fish_neural_network_classifier/refs/heads/main/gut_based/Data/gut_full_feature_table.csv")
df.head()
# Out:
#       pond  \
# 0  Gut_S10
# 1  Gut_S10
# 2  Gut_S10
# 3  Gut_S10
# 4  Gut_S10
#
#    d__Bacteria;p__Firmicutes;c__Bacilli;o__Erysipelotrichales;f__Erysipelotrichaceae  \
# 0                                             2319.0
# 1                                             3391.0
# 2                                             1338.0
# 3                                             1582.0
# 4                                             1463.0
#
#    d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Aeromonadales;f__Aeromonadaceae  \
# 0                                             2187.0
# 1                                             2071.0
# 2                                             7053.0
# 3                                            15595.0
# 4                                             3891.0
#
#    d__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiaceae  \
# 0                                             1743.0
# ...

# %%
df=df.fillna(0)
df
# Out:
#         pond  \
# 0    Gut_S10
# 1    Gut_S10
# 2    Gut_S10
# 3    Gut_S10
# 4    Gut_S10
# ..       ...
# 119   Gut_S9
# 120   Gut_S9
# 121   Gut_S9
# 122   Gut_S9
# 123   Gut_S9
#
#      d__Bacteria;p__Firmicutes;c__Bacilli;o__Erysipelotrichales;f__Erysipelotrichaceae  \
# 0                                               2319.0
# 1                                               3391.0
# 2                                               1338.0
# 3                                               1582.0
# 4                                               1463.0
# ..                                                 ...
# 119                                              104.0
# 120                                              750.0
# 121                                              183.0
# 122                                              490.0
# 123                                               42.0
#
# ...

# %%
df.dtypes
# Out:
# pond                                                                                           object
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Erysipelotrichales;f__Erysipelotrichaceae             float64
# d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Aeromonadales;f__Aeromonadaceae       float64
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiaceae                    float64
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Enterococcaceae                    float64
#                                                                                                ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Vibrionales;f__Vibrionaceae           float64
# d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Moraxellaceae      float64
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Flavobacteriales;f__Crocinitomicaceae           float64
# ...

# %%
df.describe()
# Out:
#        d__Bacteria;p__Firmicutes;c__Bacilli;o__Erysipelotrichales;f__Erysipelotrichaceae  \
# count                                         124.000000
# mean                                          831.653226
# std                                          1120.105607
# min                                             0.000000
# 25%                                           106.750000
# 50%                                           469.500000
# 75%                                          1037.750000
# max                                          6597.000000
#
#        d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Aeromonadales;f__Aeromonadaceae  \
# count                                         124.000000
# mean                                         8693.169355
# std                                          5604.123141
# min                                           167.000000
# 25%                                          3913.500000
# ...

# %%
predyktory = df.columns[1:] #podział danych na zakres 0:1
df[predyktory]=df[predyktory]/df[predyktory].max()
#df[predyktory] = normalize(df[predyktory],norm = 'max',axis = 0)
df
# Out:
#         pond  \
# 0    Gut_S10
# 1    Gut_S10
# 2    Gut_S10
# 3    Gut_S10
# 4    Gut_S10
# ..       ...
# 119   Gut_S9
# 120   Gut_S9
# 121   Gut_S9
# 122   Gut_S9
# 123   Gut_S9
#
#      d__Bacteria;p__Firmicutes;c__Bacilli;o__Erysipelotrichales;f__Erysipelotrichaceae  \
# 0                                             0.351523
# 1                                             0.514022
# 2                                             0.202819
# 3                                             0.239806
# 4                                             0.221767
# ..                                                 ...
# 119                                           0.015765
# 120                                           0.113688
# 121                                           0.027740
# 122                                           0.074276
# 123                                           0.006367
#
# ...

# %%
df['pond']=df['pond'].str.replace("Gut_S","")
df['pond']
# Out:
# 0      10
# 1      10
# 2      10
# 3      10
# 4      10
#        ..
# 119     9
# 120     9
# 121     9
# 122     9
# 123     9
# Name: pond, Length: 124, dtype: object

# %%
codes={0:[8,14,18,24,29],1:[12,16,19,23,26],2:[10,21,28,30,32],3:[9,13,17,20,27],4:[11,15,22,25,32]}
klasy = []
for x in df['pond']:
    x = int(x)
    for key, value in codes.items():
        if x in value:
            klasy.append(key)

df.insert(1,"klasy",klasy)
# Out:
# C:\Users\przem\AppData\Local\Temp\ipykernel_19916\3007053713.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(1,"klasy",klasy)

# %%
from sklearn.model_selection import train_test_split

train,test = train_test_split(df,train_size = 0.8,stratify=df["klasy"])

# %%
x_train = train[predyktory].values
y_train = train['klasy'].values
x_test = test[predyktory].values
y_test = test['klasy'].values

# %%
from keras.utils import to_categorical


y_test = to_categorical(y_test, num_classes=5)

y_train = to_categorical(y_train, num_classes=5)

# %%
model1 = keras.Sequential()
model1.add(keras.layers.Dense(560,input_shape=(len(predyktory),), activation = "relu"))
model1.add(keras.layers.Dense(230, activation = "sigmoid"))
model1.add(keras.layers.Dense(100, activation = "sigmoid"))
model1.add(keras.layers.Dense(5,activation = "softmax"))
model1.summary()
# Out:
# C:\Users\przem\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 560)            │        71,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 230)            │       129,030 │
# ...

# %%
loss = "categorical_crossentropy"#f_straty
metryka = ['accuracy']
optimizer = keras.optimizers.Adam(learning_rate = 0.01)
model1.compile(loss=loss,metrics=metryka,optimizer=optimizer)

# %%
history = model1.fit(x_train,y_train,epochs=200,shuffle=True,validation_data=[x_test,y_test])
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.1482 - loss: 2.2365 - val_accuracy: 0.2000 - val_loss: 1.8322
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1946 - loss: 1.9837 - val_accuracy: 0.2000 - val_loss: 1.9745
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2088 - loss: 1.8414 - val_accuracy: 0.2800 - val_loss: 1.5329
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4245 - loss: 1.4644 - val_accuracy: 0.2800 - val_loss: 1.4849
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4724 - loss: 1.3128 - val_accuracy: 0.3600 - val_loss: 1.3263
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5282 - loss: 1.1751 - val_accuracy: 0.4800 - val_loss: 1.2511
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6503 - loss: 0.9650 - val_accuracy: 0.5600 - val_loss: 1.1221
# Epoch 8/200
# ...

# %%
predykcja_fnn = model1.predict(x_train)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
predykcje_class = []
for x in predykcja_fnn:
    x = list(x)
    clas = x.index(max(x))
    predykcje_class.append(clas)

# %%
from sklearn.metrics import accuracy_score
predykcja_fnn.argmax(axis=1)
true_class = y_train.argmax(axis=1)
accuracy_score(true_class,predykcje_class)
# Out:
# 1.0

# %%
print(len(true_class))        # Number of true labels
print(len(predykcje_class))  # Number of predicted labels
# Out:
# 25
# 99

# %%
pd.DataFrame({'val_lose':history.history['val_loss'],'loss':history.history['loss']}).plot()
# Out:
# <Axes: >
